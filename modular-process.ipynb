# %% [markdown]
# # Use OpenAI GPT-4o to read receipts and add itemized list to a spreadhseet
#
# This setup extracts all image files from the data folder, uses GPT-4o with function calling to identify images with receipts, read the receipts, and return relevant data in a specified structure. Finally, Python uses the data to add new rows to a CSV file.

# %%
# Import modules and dependencies
import os
from utils.manage_data import import_expenses, write_expenses
from utils.process_receipt import process_receipt

# %%
# Import expenses.csv, place the data in a DataFrame, and display the data
expenses_df = import_expenses("expenses.csv")
expenses_df
# Out:
#          Date            Vendor                 Name  Quantity  Price  \
# 0  2024-05-18  Uniqlo Metrotown  W's full-zip hoodie         1   49.9
# 1  2024-05-18  Uniqlo Metrotown    K's AIRism hoodie         1   29.9
#
#    Category Payment method
# 0  clothing         credit
# 1  clothing         credit

# %%
# Get data folder
data_folder = "data"

# Get the list of files in the data folder
files = os.listdir(data_folder)

# Filter the list of files to only include image files
image_files = [file for file in files if os.path.splitext(file)[1].lower() in ['.jpg', '.jpeg', '.png', '.gif']]

# %%
# Iterate over each file in the  data folder
for index, image_file in enumerate(image_files, start=1):
    print(f"Processing image {index} of {len(image_files)}.")
    print("---------------------------")

    # Get the full path to the current image file
    image_path = os.path.join(data_folder, image_file)

    # Run process_receipt() on each file
    expenses_df = process_receipt(expenses_df, image_path)

    print('\n')

# Output the DataFrame with any new expense rows added
expenses_df
# Out:
# Processing image 1 of 7.
# ---------------------------
# Encoding image: data/receipt-07.png
# Passing image data to GPT-4o for processing...
# Response received from GPT-4o: ChatCompletion(id='chatcmpl-9Z4WZhAqDtTSbOvR5VHFsHTkQI3EW', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_lKX4c57gRMysTLcFCCUFpOEN', function=Function(arguments='{"vendor":"GardenWorks","date":"2014-05-16","items":[{"name":"Vegetable Jumbo Pack","price":5.52,"quantity":1,"category":"groceries"},{"name":"Vegetable Jumbo Pack","price":6.49,"quantity":1,"category":"groceries"},{"name":"Vegetable Assorted 10cm","price":3.39,"quantity":1,"category":"groceries"},{"name":"Tomato 10cm","price":2.97,"quantity":1,"category":"groceries"},{"name":"Organic Vegetable 10cm","price":4.43,"quantity":2,"category":"groceries"},{"name":"GV Cardboard Flat","price":0.21,"quantity":1,"category":"supplies"}],"payment_method":"credit"}', name='itemize_receipt'), type='function')]))], created=1718145899, model='gpt-4o-2024-05-13', object='chat.completion', system_fingerprint='fp_aa87380ac5', usage=CompletionUsage(completion_tokens=172, prompt_tokens=1298, total_tokens=1470))
#
# Retrieved receipt data from 2014-05-16 at GardenWorks
# Adding rows to expenses DataFrame
# Adding item: Vegetable Jumbo Pack
# Adding item: Vegetable Jumbo Pack
# Adding item: Vegetable Assorted 10cm
# Adding item: Tomato 10cm
# Adding item: Organic Vegetable 10cm
# Adding item: GV Cardboard Flat
# New rows added: 6
#
#
# Processing image 2 of 7.
# ---------------------------
# Encoding image: data/receipt-06.png
# Passing image data to GPT-4o for processing...
# Response received from GPT-4o: ChatCompletion(id='chatcmpl-9Z4Wg9MoUNvWuL9ZYCg7LMlh8rDOL', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_dBwXjWZllv2qfPeX0pVrmJAQ', function=Function(arguments='{"vendor":"Burger King","date":"2024-05-11","items":[{"name":"Crispy Chicken","price":9.14,"quantity":1,"category":"meal"},{"name":"Roadhouse Crispy Chicken","price":12.83,"quantity":1,"category":"meal"},{"name":"Fry","price":3.23,"quantity":2,"category":"meal"},{"name":"Impossible Whopper","price":8.14,"quantity":1,"category":"meal"},{"name":"Coke","price":0,"quantity":2,"category":"meal"}],"payment_method":"credit"}', name='itemize_receipt'), type='function')]))], created=1718145906, model='gpt-4o-2024-05-13', object='chat.completion', system_fingerprint='fp_aa87380ac5', usage=CompletionUsage(completion_tokens=134, prompt_tokens=958, total_tokens=1092))
#
# Retrieved receipt data from 2024-05-11 at Burger King
# Adding rows to expenses DataFrame
# Adding item: Crispy Chicken
# Adding item: Roadhouse Crispy Chicken
# Adding item: Fry
# Adding item: Impossible Whopper
# Adding item: Coke
# New rows added: 5
#
#
# Processing image 3 of 7.
# ---------------------------
# Encoding image: data/receipt-04.png
# Passing image data to GPT-4o for processing...
# Response received from GPT-4o: ChatCompletion(id='chatcmpl-9Z4WmxLy7pAgotxQPlPJPA0dUOYRc', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_up037gstDxT9CqAdrBkqDKQx', function=Function(arguments='{\n  "vendor": "Costco Wholesale",\n  "date": "2023-07-05",\n  "items": [\n    {\n      "name": "Aussie Bites",\n      "price": 15.49,\n      "quantity": 1,\n      "category": "groceries"\n    },\n    {\n      "name": "Shrimp Tacos",\n      "price": 24.50,\n      "quantity": 1,\n      "category": "groceries"\n    },\n    {\n      "name": "Always INR200",\n      "price": 4.09,\n      "quantity": 1,\n      "category": "groceries"\n    },\n    {\n      "name": "TP/222886",\n      "price": 10.99,\n      "quantity": 1,\n      "category": "groceries"\n    },\n    {\n      "name": "Bagel Chips",\n      "price": 63.47,\n      "quantity": 1,\n      "category": "groceries"\n    }\n  ],\n  "payment_method": "debit"\n}', name='itemize_receipt'), type='function')]))], created=1718145912, model='gpt-4o-2024-05-13', object='chat.completion', system_fingerprint='fp_aa87380ac5', usage=CompletionUsage(completion_tokens=236, prompt_tokens=958, total_tokens=1194))
#
# Retrieved receipt data from 2023-07-05 at Costco Wholesale
# Adding rows to expenses DataFrame
# Adding item: Aussie Bites
# Adding item: Shrimp Tacos
# Adding item: Always INR200
# Adding item: TP/222886
# Adding item: Bagel Chips
# New rows added: 5
#
#
# Processing image 4 of 7.
# ---------------------------
# Encoding image: data/receipt-05.png
# Passing image data to GPT-4o for processing...
# Response received from GPT-4o: ChatCompletion(id='chatcmpl-9Z4WuWzlmhUkjClV3JLkGoyn250zn', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_gt4jhxEirSfgJkax8c4nC0U9', function=Function(arguments='{"vendor":"King\'s Way Alterations","date":"2023-04-22","items":[{"name":"Jacket Fix and Steam","price":30,"quantity":1,"category":"clothing"}],"payment_method":"other"}', name='itemize_receipt'), type='function')]))], created=1718145920, model='gpt-4o-2024-05-13', object='chat.completion', system_fingerprint='fp_aa87380ac5', usage=CompletionUsage(completion_tokens=59, prompt_tokens=958, total_tokens=1017))
#
# Retrieved receipt data from 2023-04-22 at King's Way Alterations
# Adding rows to expenses DataFrame
# Adding item: Jacket Fix and Steam
# New rows added: 1
#
#
# Processing image 5 of 7.
# ---------------------------
# Encoding image: data/receipt-01.png
# Passing image data to GPT-4o for processing...
# Response received from GPT-4o: ChatCompletion(id='chatcmpl-9Z4X1mw9aRgMK5bTFB3nd4TosRyi4', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_AyuRPwfW6VABHZoqjewHMrah', function=Function(arguments='{"vendor":"Panago","date":"2024-05-11","items":[{"name":"MEDIUM Deluxe (pepperoni) Original Crust","price":18.25,"quantity":1,"category":"meal"},{"name":"MEDIUM Veggie KMEDK Thin Crust","price":20.25,"quantity":1,"category":"meal"}],"payment_method":"cash"}', name='itemize_receipt'), type='function')]))], created=1718145927, model='gpt-4o-2024-05-13', object='chat.completion', system_fingerprint='fp_aa87380ac5', usage=CompletionUsage(completion_tokens=90, prompt_tokens=958, total_tokens=1048))
#
# Retrieved receipt data from 2024-05-11 at Panago
# Adding rows to expenses DataFrame
# Adding item: MEDIUM Deluxe (pepperoni) Original Crust
# Adding item: MEDIUM Veggie KMEDK Thin Crust
# New rows added: 2
#
#
# Processing image 6 of 7.
# ---------------------------
# Encoding image: data/receipt-02.png
# Passing image data to GPT-4o for processing...
# Response received from GPT-4o: ChatCompletion(id='chatcmpl-9Z4X6vgHBBtHCXCqdD7iHsNrqFVZH', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_v8bBqIv5KCDqWKbmDkvNiLlO', function=Function(arguments='{"vendor":"Uniqlo Metrotown","date":"2024-05-18","items":[{"name":"W\'s full-zip hoodie","price":49.90,"quantity":1,"category":"clothing"},{"name":"K\'s AIRism hoodie","price":29.90,"quantity":1,"category":"clothing"}],"payment_method":"credit"}', name='itemize_receipt'), type='function')]))], created=1718145932, model='gpt-4o-2024-05-13', object='chat.completion', system_fingerprint='fp_aa87380ac5', usage=CompletionUsage(completion_tokens=86, prompt_tokens=958, total_tokens=1044))
#
# Retrieved receipt data from 2024-05-18 at Uniqlo Metrotown
# Adding rows to expenses DataFrame
# Adding item: W's full-zip hoodie
# Adding item: K's AIRism hoodie
# New rows added: 2
#
#
# Processing image 7 of 7.
# ---------------------------
# Encoding image: data/receipt-03.jpg
# Passing image data to GPT-4o for processing...
# Response received from GPT-4o: ChatCompletion(id='chatcmpl-9Z4XDs8JCcoP9hJUTKeLW61UwHEuV', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='It looks like you have a handful of small, colorful pig figurines. If you need any specific information or assistance related to these items, please let me know!', role='assistant', function_call=None, tool_calls=None))], created=1718145939, model='gpt-4o-2024-05-13', object='chat.completion', system_fingerprint='fp_aa87380ac5', usage=CompletionUsage(completion_tokens=34, prompt_tokens=958, total_tokens=992))
#
# WARNING:
# It looks like you have a handful of small, colorful pig figurines. If you need any specific information or assistance related to these items, please let me know!
#           Date                  Vendor  \
# 0   2024-05-18        Uniqlo Metrotown
# 1   2024-05-18        Uniqlo Metrotown
# 2   2014-05-16             GardenWorks
# 3   2014-05-16             GardenWorks
# 4   2014-05-16             GardenWorks
# 5   2014-05-16             GardenWorks
# 6   2014-05-16             GardenWorks
# 7   2014-05-16             GardenWorks
# 8   2024-05-11             Burger King
# 9   2024-05-11             Burger King
# 10  2024-05-11             Burger King
# 11  2024-05-11             Burger King
# 12  2024-05-11             Burger King
# 13  2023-07-05        Costco Wholesale
# 14  2023-07-05        Costco Wholesale
# 15  2023-07-05        Costco Wholesale
# 16  2023-07-05        Costco Wholesale
# 17  2023-07-05        Costco Wholesale
# 18  2023-04-22  King's Way Alterations
# 19  2024-05-11                  Panago
# 20  2024-05-11                  Panago
# 21  2024-05-18        Uniqlo Metrotown
# 22  2024-05-18        Uniqlo Metrotown
#
#                                         Name  Quantity  Price   Category  \
# 0                        W's full-zip hoodie         1  49.90   clothing
# 1                          K's AIRism hoodie         1  29.90   clothing
# 2                       Vegetable Jumbo Pack         1   5.52  groceries
# 3                       Vegetable Jumbo Pack         1   6.49  groceries
# 4                    Vegetable Assorted 10cm         1   3.39  groceries
# 5                                Tomato 10cm         1   2.97  groceries
# 6                     Organic Vegetable 10cm         2   4.43  groceries
# 7                          GV Cardboard Flat         1   0.21   supplies
# 8                             Crispy Chicken         1   9.14       meal
# 9                   Roadhouse Crispy Chicken         1  12.83       meal
# 10                                       Fry         2   3.23       meal
# 11                        Impossible Whopper         1   8.14       meal
# 12                                      Coke         2   0.00       meal
# 13                              Aussie Bites         1  15.49  groceries
# 14                              Shrimp Tacos         1  24.50  groceries
# 15                             Always INR200         1   4.09  groceries
# 16                                 TP/222886         1  10.99  groceries
# 17                               Bagel Chips         1  63.47  groceries
# 18                      Jacket Fix and Steam         1  30.00   clothing
# 19  MEDIUM Deluxe (pepperoni) Original Crust         1  18.25       meal
# 20            MEDIUM Veggie KMEDK Thin Crust         1  20.25       meal
# 21                       W's full-zip hoodie         1  49.90   clothing
# 22                         K's AIRism hoodie         1  29.90   clothing
#
#    Payment method
# 0          credit
# 1          credit
# 2          credit
# 3          credit
# 4          credit
# 5          credit
# 6          credit
# 7          credit
# 8          credit
# 9          credit
# 10         credit
# 11         credit
# 12         credit
# 13          debit
# 14          debit
# 15          debit
# 16          debit
# 17          debit
# 18          other
# 19           cash
# 20           cash
# 21         credit
# 22         credit

# %%
# Use the DataFrame to write the updated expenses.csv file
write_expenses(expenses_df, "expenses.csv")
